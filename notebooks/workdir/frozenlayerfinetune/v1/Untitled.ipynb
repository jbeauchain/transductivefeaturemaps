# %%
import os

base = "/opt/app-root/src/projects/transductivefeaturemaps/workdir"

for root, dirs, files in os.walk(base):
    for file in files:
        if "metrics" in file or file.endswith(".png") or file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# /opt/app-root/src/projects/transductivefeaturemaps/workdir/progressivefinetune/v1/checkpoint/unet_att_d_ep10/training_history.csv
# /opt/app-root/src/projects/transductivefeaturemaps/workdir/progressivefinetune/v1/checkpoint/unet_att_d_ep4/training_history.csv
# /opt/app-root/src/projects/transductivefeaturemaps/workdir/progressivefinetune/v2/croplands3-2.1.1_finetune_ZM_only.csv
# /opt/app-root/src/projects/transductivefeaturemaps/workdir/unfreezefinetune/croplands3-2.1.1_finetune_ZM_only.csv
# /opt/app-root/src/projects/transductivefeaturemaps/workdir/unfreezefinetune/v1/checkpoint/unet_att_d_ep80/training_history.csv
# /opt/app-root/src/projects/transductivefeaturemaps/workdir/unfreezefinetune/v1/checkpoint/unet_att_d_ep80/.ipynb_checkpoints/training_history-checkpoint.csv
# /opt/app-root/src/projects/transductivefeaturemaps/workdir/unfreezefinetune/v1/checkpoint/unet_att_d_ep2/training_history.csv
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("croplands3-2.1.1_finetune_ZM_only.csv")

print(df.columns)  # see what columns exist

plt.plot(df.index, df.iloc[:, 0])
plt.title("Metric Over Time")
plt.show()
# Out:
# Index(['name', 'assignment_id', 'Class', 'dataset', 'rscore', 'rscore2',
#        'Rscore', 'x', 'y', 'farea', 'fprop', 'cntry', 'year', 'label_group',
#        'usage', 'label', 'image'],
#       dtype='object')
