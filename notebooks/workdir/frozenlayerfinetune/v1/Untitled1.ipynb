# %%
print("test")
# Out:
# test

# %%
import os
print(os.getcwd())
print(os.listdir("."))
# Out:
# /opt/app-root/src/projects/transductivefeaturemaps/workdir/frozenlayerfinetune/v1
# ['checkpoints', '.ipynb_checkpoints', 'Untitled1.ipynb', 'logs ', 'Untitled.ipynb', 'croplands3-2.1.1_finetune_ZM_only.csv']

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if "metrics" in file:
            print(os.path.join(root, file))

# %%
print("test")
# Out:
# test

# %%
import os
print(os.listdir("logs "))
# Out:
# []
